# %%
import pandas as pd
import numpy as np

# %%
deprem =pd.read_csv(r'C:\Users\Eren\Desktop\jupyter\jupyter data\Deprem Senaryosu Analiz Sonuçlar_.csv')

# %%
deprem
# Out:
#      _id     ilce_adi mahalle_adi  mahalle_koy_uavt  \
# 0      1       ADALAR   BURGAZADA             40139
# 1      2       ADALAR  HEYBELÝADA             40142
# 2      3       ADALAR   KINALIADA             40143
# 3      4       ADALAR       MADEN             40140
# 4      5       ADALAR       NÝZAM             40141
# ..   ...          ...         ...               ...
# 954  955  ZEYTÝNBURNU       SÜMER             40831
# 955  956  ZEYTÝNBURNU      TELSÝZ             40839
# 956  957  ZEYTÝNBURNU  VELÝEFENDÝ             40836
# 957  958  ZEYTÝNBURNU   YENÝDOÐAN             40833
# 958  959  ZEYTÝNBURNU   YEÞÝLTEPE             40835
#
#      cok_agir_hasarli_bina_sayisi  agir_hasarli_bina_sayisi  \
# 0                              54                        99
# 1                             101                       175
# 2                              53                        97
# 3                             104                       192
# ...

# %%
deprem['mahalle_adi']=deprem['mahalle_adi'].apply(lambda x: x.replace('Ý','İ'))
deprem['mahalle_adi']=deprem['mahalle_adi'].apply(lambda x: x.replace('Ð','Ğ'))
deprem['mahalle_adi']=deprem['mahalle_adi'].apply(lambda x: x.replace('Þ','Ş'))
deprem['ilce_adi']=deprem['ilce_adi'].apply(lambda x: x.replace('Ý','İ'))
deprem['ilce_adi']=deprem['ilce_adi'].apply(lambda x: x.replace('Ð','Ğ'))
deprem['ilce_adi']=deprem['ilce_adi'].apply(lambda x: x.replace('Þ','Ş'))
deprem
# Out:
#      _id     ilce_adi mahalle_adi  mahalle_koy_uavt  \
# 0      1       ADALAR   BURGAZADA             40139
# 1      2       ADALAR  HEYBELİADA             40142
# 2      3       ADALAR   KINALIADA             40143
# 3      4       ADALAR       MADEN             40140
# 4      5       ADALAR       NİZAM             40141
# ..   ...          ...         ...               ...
# 954  955  ZEYTİNBURNU       SÜMER             40831
# 955  956  ZEYTİNBURNU      TELSİZ             40839
# 956  957  ZEYTİNBURNU  VELİEFENDİ             40836
# 957  958  ZEYTİNBURNU   YENİDOĞAN             40833
# 958  959  ZEYTİNBURNU   YEŞİLTEPE             40835
#
#      cok_agir_hasarli_bina_sayisi  agir_hasarli_bina_sayisi  \
# 0                              54                        99
# 1                             101                       175
# 2                              53                        97
# 3                             104                       192
# ...

# %%
deprem['toplam_hasarli_bina'] = deprem["cok_agir_hasarli_bina_sayisi"] + deprem["agir_hasarli_bina_sayisi"] + deprem["orta_hasarli_bina_sayisi"] + deprem["hafif_hasarli_bina_sayisi"]

# %%
deprem
# Out:
#      _id     ilce_adi mahalle_adi  mahalle_koy_uavt  \
# 0      1       ADALAR   BURGAZADA             40139
# 1      2       ADALAR  HEYBELİADA             40142
# 2      3       ADALAR   KINALIADA             40143
# 3      4       ADALAR       MADEN             40140
# 4      5       ADALAR       NİZAM             40141
# ..   ...          ...         ...               ...
# 954  955  ZEYTİNBURNU       SÜMER             40831
# 955  956  ZEYTİNBURNU      TELSİZ             40839
# 956  957  ZEYTİNBURNU  VELİEFENDİ             40836
# 957  958  ZEYTİNBURNU   YENİDOĞAN             40833
# 958  959  ZEYTİNBURNU   YEŞİLTEPE             40835
#
#      cok_agir_hasarli_bina_sayisi  agir_hasarli_bina_sayisi  \
# 0                              54                        99
# 1                             101                       175
# 2                              53                        97
# 3                             104                       192
# ...

# %%
deprem = deprem.drop(columns=["cok_agir_hasarli_bina_sayisi","agir_hasarli_bina_sayisi","orta_hasarli_bina_sayisi", "hafif_hasarli_bina_sayisi"])

# %%
type(deprem)
# Out:
# pandas.core.frame.DataFrame

# %%
deprem
# Out:
#      _id     ilce_adi mahalle_adi  mahalle_koy_uavt  can_kaybi_sayisi  \
# 0      1       ADALAR   BURGAZADA             40139                 8
# 1      2       ADALAR  HEYBELİADA             40142                25
# 2      3       ADALAR   KINALIADA             40143                 5
# 3      4       ADALAR       MADEN             40140                22
# 4      5       ADALAR       NİZAM             40141                16
# ..   ...          ...         ...               ...               ...
# 954  955  ZEYTİNBURNU       SÜMER             40831                87
# 955  956  ZEYTİNBURNU      TELSİZ             40839                84
# 956  957  ZEYTİNBURNU  VELİEFENDİ             40836                66
# 957  958  ZEYTİNBURNU   YENİDOĞAN             40833                24
# 958  959  ZEYTİNBURNU   YEŞİLTEPE             40835                45
#
#      agir_yarali_sayisi  hastanede_tedavi_sayisi  hafif_yarali_sayisi  \
# ...

# %%
deprem = deprem.drop(columns=['mahalle_koy_uavt','dogalgaz_boru_hasari','icme_suyu_boru_hasari','atik_su_boru_hasari'])

# %%
deprem
# Out:
#      _id     ilce_adi mahalle_adi  can_kaybi_sayisi  agir_yarali_sayisi  \
# 0      1       ADALAR   BURGAZADA                 8                   6
# 1      2       ADALAR  HEYBELİADA                25                  21
# 2      3       ADALAR   KINALIADA                 5                   3
# 3      4       ADALAR       MADEN                22                  18
# 4      5       ADALAR       NİZAM                16                  13
# ..   ...          ...         ...               ...                 ...
# 954  955  ZEYTİNBURNU       SÜMER                87                  47
# 955  956  ZEYTİNBURNU      TELSİZ                84                  48
# 956  957  ZEYTİNBURNU  VELİEFENDİ                66                  38
# 957  958  ZEYTİNBURNU   YENİDOĞAN                24                  13
# 958  959  ZEYTİNBURNU   YEŞİLTEPE                45                  25
#
#      hastanede_tedavi_sayisi  hafif_yarali_sayisi  gecici_barinma  \
# ...

# %%
mahalle_sayisi = deprem.groupby("ilce_adi")["mahalle_adi"].aggregate("count").values

# %%
arrayMahalleSayisi=mahalle_sayisi.reshape(39,1)

# %%
deprem=deprem.drop(columns="mahalle_adi")
deprem
# Out:
#      _id     ilce_adi  can_kaybi_sayisi  agir_yarali_sayisi  \
# 0      1       ADALAR                 8                   6
# 1      2       ADALAR                25                  21
# 2      3       ADALAR                 5                   3
# 3      4       ADALAR                22                  18
# 4      5       ADALAR                16                  13
# ..   ...          ...               ...                 ...
# 954  955  ZEYTİNBURNU                87                  47
# 955  956  ZEYTİNBURNU                84                  48
# 956  957  ZEYTİNBURNU                66                  38
# 957  958  ZEYTİNBURNU                24                  13
# 958  959  ZEYTİNBURNU                45                  25
#
#      hastanede_tedavi_sayisi  hafif_yarali_sayisi  gecici_barinma  \
# 0                         24                   42             398
# 1                         66                  113             763
# ...

# %%
deprem=deprem.groupby("ilce_adi").sum()
deprem
# Out:
#                  _id  can_kaybi_sayisi  agir_yarali_sayisi  \
# ilce_adi
# ADALAR            15                76                  61
# ARNAVUTKÖY       931                 0                   0
# ATAŞEHİR         884                89                  47
# AVCILAR          655               465                 239
# BAHÇELİEVLER    1078              1633                 879
# BAKIRKÖY        1665              1046                 581
# BAYRAMPAŞA      1474               520                 340
# BAĞCILAR        1793              1179                 652
# BAŞAKŞEHİR      1235                71                  45
# BEYKOZ          8325                25                  16
# BEYLİKDÜZÜ      2125               527                 276
# BEYOĞLU        10800               217                 150
# BEŞİKTAŞ        3473                26                  14
# BÜYÜKÇEKMECE    6588               288                 154
# ESENLER         5672               638                 352
# ...

# %%
deprem["mahalle_sayisi"] = arrayMahalleSayisi

# %%
deprem
# Out:
#                  _id  can_kaybi_sayisi  agir_yarali_sayisi  \
# ilce_adi
# ADALAR            15                76                  61
# ARNAVUTKÖY       931                 0                   0
# ATAŞEHİR         884                89                  47
# AVCILAR          655               465                 239
# BAHÇELİEVLER    1078              1633                 879
# BAKIRKÖY        1665              1046                 581
# BAYRAMPAŞA      1474               520                 340
# BAĞCILAR        1793              1179                 652
# BAŞAKŞEHİR      1235                71                  45
# BEYKOZ          8325                25                  16
# BEYLİKDÜZÜ      2125               527                 276
# BEYOĞLU        10800               217                 150
# BEŞİKTAŞ        3473                26                  14
# BÜYÜKÇEKMECE    6588               288                 154
# ESENLER         5672               638                 352
# ...

# %%
deprem["yarali_ve_tedavi_sayisi"]= deprem["agir_yarali_sayisi"] + deprem["hastanede_tedavi_sayisi"] + deprem["hafif_yarali_sayisi"]
deprem
# Out:
#                  _id  can_kaybi_sayisi  agir_yarali_sayisi  \
# ilce_adi
# ADALAR            15                76                  61
# ARNAVUTKÖY       931                 0                   0
# ATAŞEHİR         884                89                  47
# AVCILAR          655               465                 239
# BAHÇELİEVLER    1078              1633                 879
# BAKIRKÖY        1665              1046                 581
# BAYRAMPAŞA      1474               520                 340
# BAĞCILAR        1793              1179                 652
# BAŞAKŞEHİR      1235                71                  45
# BEYKOZ          8325                25                  16
# BEYLİKDÜZÜ      2125               527                 276
# BEYOĞLU        10800               217                 150
# BEŞİKTAŞ        3473                26                  14
# BÜYÜKÇEKMECE    6588               288                 154
# ESENLER         5672               638                 352
# ...

# %%
deprem = deprem.drop(columns=["agir_yarali_sayisi","hastanede_tedavi_sayisi","hafif_yarali_sayisi","_id"])
deprem
# Out:
#                can_kaybi_sayisi  gecici_barinma  toplam_hasarli_bina  \
# ilce_adi
# ADALAR                       76            3115                 4892
# ARNAVUTKÖY                    0            5815                 6938
# ATAŞEHİR                     89           14702                10183
# AVCILAR                     465           34941                16324
# BAHÇELİEVLER               1633           61199                17640
# BAKIRKÖY                   1046           28910                 9421
# BAYRAMPAŞA                  520           23064                13270
# BAĞCILAR                   1179           59513                26019
# BAŞAKŞEHİR                   71           13397                 9910
# BEYKOZ                       25            5937                10668
# BEYLİKDÜZÜ                  527           26670                 8606
# BEYOĞLU                     217           10295                11541
# ...

# %%
deprem["mahalle_basina_yarali_sayisi"]= deprem["yarali_ve_tedavi_sayisi"] / deprem["mahalle_sayisi"]
deprem
# Out:
#                can_kaybi_sayisi  gecici_barinma  toplam_hasarli_bina  \
# ilce_adi
# ADALAR                       76            3115                 4892
# ARNAVUTKÖY                    0            5815                 6938
# ATAŞEHİR                     89           14702                10183
# AVCILAR                     465           34941                16324
# BAHÇELİEVLER               1633           61199                17640
# BAKIRKÖY                   1046           28910                 9421
# BAYRAMPAŞA                  520           23064                13270
# BAĞCILAR                   1179           59513                26019
# BAŞAKŞEHİR                   71           13397                 9910
# BEYKOZ                       25            5937                10668
# BEYLİKDÜZÜ                  527           26670                 8606
# BEYOĞLU                     217           10295                11541
# ...

# %%
deprem["hasarli_bina_basina_can_kaybi_sayisi"]= deprem["can_kaybi_sayisi"]/ deprem["toplam_hasarli_bina"] *100
deprem
# Out:
#                can_kaybi_sayisi  gecici_barinma  toplam_hasarli_bina  \
# ilce_adi
# ADALAR                       76            3115                 4892
# ARNAVUTKÖY                    0            5815                 6938
# ATAŞEHİR                     89           14702                10183
# AVCILAR                     465           34941                16324
# BAHÇELİEVLER               1633           61199                17640
# BAKIRKÖY                   1046           28910                 9421
# BAYRAMPAŞA                  520           23064                13270
# BAĞCILAR                   1179           59513                26019
# BAŞAKŞEHİR                   71           13397                 9910
# BEYKOZ                       25            5937                10668
# BEYLİKDÜZÜ                  527           26670                 8606
# BEYOĞLU                     217           10295                11541
# ...

# %%
ilceyeGoreGeciciBarinma = deprem.groupby("ilce_adi")["gecici_barinma"].aggregate("sum")
toplamGeciciBarinma=ilceyeGoreGeciciBarinma.values.sum()

# %%
round(toplamGeciciBarinma/3.4) # ortalama hane bireyi sayisina gore gecici barinma icin ihtiyac duyulan yaklasik daire sayisi
# Out:
# 245858

# %%
mahalle_sayisi_sep= pd.cut(deprem["mahalle_sayisi"],[0,15,30,45,62])

# %%
depremCan=deprem.sort_values(by=['can_kaybi_sayisi'])

# %%
deprem=deprem[['can_kaybi_sayisi','yarali_ve_tedavi_sayisi','toplam_hasarli_bina','hasarli_bina_basina_can_kaybi_sayisi','mahalle_basina_yarali_sayisi','mahalle_sayisi','gecici_barinma']]

# %%
depremCan
# Out:
#                can_kaybi_sayisi  gecici_barinma  toplam_hasarli_bina  \
# ilce_adi
# ARNAVUTKÖY                    0            5815                 6938
# ŞİLE                          0             876                 3304
# ÇEKMEKÖY                      1            3922                 4519
# ÇATALCA                       4            1933                 6073
# BEYKOZ                       25            5937                10668
# BEŞİKTAŞ                     26            4096                 4545
# SARIYER                      33            6616                 9930
# ÜMRANİYE                     42           16345                14921
# SANCAKTEPE                   48           12967                 9772
# ŞİŞLİ                        55            4845                 5616
# SULTANGAZİ                   57           10524                 8994
# SİLİVRİ                      58           13481                21303
# ...

# %%
deprem.groupby(["ilce_adi","toplam_hasarli_bina"])[["can_kaybi_sayisi"]].mean()
# Out:
#                                    can_kaybi_sayisi
# ilce_adi      toplam_hasarli_bina
# ADALAR        4892                             76.0
# ARNAVUTKÖY    6938                              0.0
# ATAŞEHİR      10183                            89.0
# AVCILAR       16324                           465.0
# BAHÇELİEVLER  17640                          1633.0
# BAKIRKÖY      9421                           1046.0
# BAYRAMPAŞA    13270                           520.0
# BAĞCILAR      26019                          1179.0
# BAŞAKŞEHİR    9910                             71.0
# BEYKOZ        10668                            25.0
# BEYLİKDÜZÜ    8606                            527.0
# BEYOĞLU       11541                           217.0
# BEŞİKTAŞ      4545                             26.0
# BÜYÜKÇEKMECE  18063                           288.0
# ESENLER       13245                           638.0
# ESENYURT      24914                          1003.0
# ...
